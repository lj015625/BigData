# %%
import os
from IPython.display import display, Image

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Pickles12\\Documents\\BIA 6312 BCA Intro to Python - Oct 2017\\Class Scripts 20171018'

# %%
import pandas as pd
pd.__version__
# Out:
# '0.20.1'

# %% [markdown]
# Why Pandas - **Code Simplified**

# %%
#72 Lines of Code Needed to Answer Our Business Question Without Pandas
display(Image('C:\\Users\\Pickles12\\Documents\\BIA 6312 BCA Intro to Python - Oct 2017\\Images\\wo_pandasA.png'))
display(Image('C:\\Users\\Pickles12\\Documents\\BIA 6312 BCA Intro to Python - Oct 2017\\Images\\wo_pandasB.png'))
display(Image('C:\\Users\\Pickles12\\Documents\\BIA 6312 BCA Intro to Python - Oct 2017\\Images\\wo_pandasC.png'))

# %% [markdown]
# # Data Manipulation with Pandas

# %% [markdown]
# Pandas is a newer package built on top of NumPy, and provides an efficient implementation of a DataFrame.
#
# DataFrames are essentially multidimensional arrays with attached row and column labels, and often with heterogeneous types and/or missing data. As well as offering a convenient storage interface for labeled data, Pandas implements a number of powerful data operations familiar to users of both database frameworks and spreadsheet programs.
#
# Pandas, and in particular its Series and DataFrame objects, builds on the NumPy array structure and provides efficient access to these sorts of "data munging" tasks that occupy much of a data scientist's time.
#
# **Dataframe objects are AT THE CORE of PANDAS

# %%
import datetime
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from matplotlib import style
style.use ('ggplot')

# %%
start = datetime.datetime(2010,1,1)
end = datetime.datetime(2017,8,1)

# %%
print(start,end)
# Out:
# 2010-01-01 00:00:00 2017-08-01 00:00:00

# %%
df = web.DataReader('s','yahoo',start,end)

# %%
print (df.head())
# Out:
#             Open  High   Low  Close  Adj Close    Volume
# Date
# 2010-01-04  3.71  3.92  3.70   3.90       3.90  59308100
# 2010-01-05  3.92  4.20  3.90   4.13       4.13  95568900
# 2010-01-06  4.13  4.23  4.02   4.09       4.09  38719300
# 2010-01-07  4.15  4.17  3.96   3.97       3.97  58800100
# 2010-01-08  3.96  4.00  3.91   3.95       3.95  20290900

# %%
df['Adj Close'].plot()

# %%
plt.show()

# %%
df = pd.read_csv("weather_data.csv")# can use single ticks(') also

# %%
df = pd.read_excel("weather_data_EXCEL.xlsx","weather_data")# can use single ticks(') also

# %%
df # Dataframes are all about Rows and Columns
# It's a tabular data structure
# Out:
#         day   temp  windspeed  event
# 0 2017-01-01    32          6  sunny
# 1 2017-01-02    35          7  sunny
# 2 2017-01-03    44          8  rainy
# 3 2017-01-04    21         22   snow
# 4 2017-01-05    20         14   snow
# 5 2017-01-06    17          7  rainy
# 6 2017-01-07    21          5   snow

# %%
weather_data = {
'day':['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017','1/7/2017'],
'temp':[32,35,44,21,20,17,21],
'windspeed':[6,7,8,22,14,7,5],
'event':['sunny','sunny','rainy','snow','snow','rainy','snow']
}

df2 = pd.DataFrame(weather_data)

# %%
# What is the shape(dimensions) of the dataframe
df2.shape
# Out:
# (7, 4)

# %%
rows, columns = df2.shape
rows
# Out:
# 7

# %%
columns
# Out:
# 4

# %%
df2.head()# prints top 5 rows of df by default
#df.head(3)
# Out:
#         day  event  temp  windspeed
# 0  1/1/2017  sunny    32          6
# 1  1/2/2017  sunny    35          7
# 2  1/3/2017  rainy    44          8
# 3  1/4/2017   snow    21         22
# 4  1/5/2017   snow    20         14

# %%
df2.tail(2)#print last two rows of dataframe
# Out:
#         day  event  temp  windspeed
# 5  1/6/2017  rainy    17          7
# 6  1/7/2017   snow    21          5

# %%
#print rows 2 - 4
df2[2:5]#starts with row 2 but does print row 5
# Out:
#         day  event  temp  windspeed
# 2  1/3/2017  rainy    44          8
# 3  1/4/2017   snow    21         22
# 4  1/5/2017   snow    20         14

# %%
#want to print everything in df
df2[:]
#df - does same thing: prints everything : BE CAREFULL!!!!
# Out:
#         day  event  temp  windspeed
# 0  1/1/2017  sunny    32          6
# 1  1/2/2017  sunny    35          7
# 2  1/3/2017  rainy    44          8
# 3  1/4/2017   snow    21         22
# 4  1/5/2017   snow    20         14
# 5  1/6/2017  rainy    17          7
# 6  1/7/2017   snow    21          5

# %%
# print column names
df2.columns
# Out:
# Index(['day', 'event', 'temp', 'windspeed'], dtype='object')

# %%
df2.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# 6    1/7/2017
# Name: day, dtype: object

# %%
#df.event
df2['event']# either way works, this way is the same as dictionary
# Out:
# 0    sunny
# 1    sunny
# 2    rainy
# 3     snow
# 4     snow
# 5    rainy
# 6     snow
# Name: event, dtype: object

# %%
type(df2['event'])
# Out:
# pandas.core.series.Series

# %%
type(df2['windspeed'])
# Out:
# pandas.core.series.Series

# %%
df2[['day','event']]
# Out:
#         day  event
# 0  1/1/2017  sunny
# 1  1/2/2017  sunny
# 2  1/3/2017  rainy
# 3  1/4/2017   snow
# 4  1/5/2017   snow
# 5  1/6/2017  rainy
# 6  1/7/2017   snow

# %%
df2['temp'].max()
# Out:
# 44

# %%
df2
# Out:
#         day  event  temp  windspeed
# 0  1/1/2017  sunny    32          6
# 1  1/2/2017  sunny    35          7
# 2  1/3/2017  rainy    44          8
# 3  1/4/2017   snow    21         22
# 4  1/5/2017   snow    20         14
# 5  1/6/2017  rainy    17          7
# 6  1/7/2017   snow    21          5

# %%
df2['temp'].min()
# Out:
# 17

# %%
df2
# Out:
#         day  event  temp  windspeed
# 0  1/1/2017  sunny    32          6
# 1  1/2/2017  sunny    35          7
# 2  1/3/2017  rainy    44          8
# 3  1/4/2017   snow    21         22
# 4  1/5/2017   snow    20         14
# 5  1/6/2017  rainy    17          7
# 6  1/7/2017   snow    21          5

# %%
df2['temp'].mean()
# Out:
# 27.142857142857142

# %%
df2['temp'].std()
# Out:
# 9.99047165100446

# %%
# print basic statistics on any numerical columns
# Known as Descriptive Statistics
df2.describe()
# Out:
#             temp  windspeed
# count   7.000000   7.000000
# mean   27.142857   9.857143
# std     9.990472   6.094494
# min    17.000000   5.000000
# 25%    20.500000   6.500000
# 50%    21.000000   7.000000
# 75%    33.500000  11.000000
# max    44.000000  22.000000

# %%
# dataframe conditional statements
df2[df2.temp>=30]
# Out:
#         day  event  temp  windspeed
# 0  1/1/2017  sunny    32          6
# 1  1/2/2017  sunny    35          7
# 2  1/3/2017  rainy    44          8

# %%
df2[df2.temp!=44]
# Out:
#         day  event  temp  windspeed
# 0  1/1/2017  sunny    32          6
# 1  1/2/2017  sunny    35          7
# 3  1/4/2017   snow    21         22
# 4  1/5/2017   snow    20         14
# 5  1/6/2017  rainy    17          7
# 6  1/7/2017   snow    21          5

# %%
df2[df2.temp==df.temp.max()]
# Out:
#         day  event  temp  windspeed
# 2  1/3/2017  rainy    44          8

# %%
# don't want to print entire row then:
df2[['day','temp']][df2.temp==df.temp.max()]
# Out:
#         day  temp
# 2  1/3/2017    44

# %%
df2[['day','temp','windspeed']][df2['event']=='snow']
# Out:
#         day  temp  windspeed
# 3  1/4/2017    21         22
# 4  1/5/2017    20         14
# 6  1/7/2017    21          5

# %% [markdown]
# **Exercise 1
# 1. Create a new notebook
# 2. Name it Consumer Complaints
# 3. Import Numpy, Pandas, Matplotlib packages and give each of them an alias
# 4. Print your current working directory
# 5. Create dataframe df_c_complaints using Consumer_Complaints.csv file
# 6. Print the number of rows(observations) and the number of columns
# 7. Print the top 3 rows of the dataframe
# 8. Print the last 3 records of the dataframe
# 9. Print rows 7 to 13
# 10. Group the'Product' column and do a value count of each group

# %%
df_c_complaints = pd.read_csv("Consumer_Complaints.csv")

# %%
df_c_complaints.shape
# Out:
# (878848, 18)

# %%
#tab key shortcut option
df_c_complaints.head(3)
# Out:
#   Date received           Product     Sub-product  \
# 0    03/12/2014          Mortgage  Other mortgage
# 1    10/01/2016  Credit reporting             NaN
# 2    10/17/2016     Consumer Loan    Vehicle loan
#
#                                       Issue       Sub-issue  \
# 0  Loan modification,collection,foreclosure             NaN
# 1    Incorrect information on credit report  Account status
# 2                Managing the loan or lease             NaN
#
#                         Consumer complaint narrative  \
# 0                                                NaN
# 1  I have outdated information on my credit repor...
# 2  I purchased a new car on XXXX XXXX. The car de...
#
#                              Company public response  \
# 0                                                NaN
# 1  Company has responded to the consumer and the ...
# 2                                                NaN
#
#                                   Company State ZIP code            Tags  \
# ...

# %%
df_c_complaints.tail(3)
# Out:
#        Date received          Product                  Sub-product  \
# 878845    01/04/2017         Mortgage  Conventional fixed mortgage
# 878846    09/28/2015  Debt collection     Non-federal student loan
# 878847    08/19/2016  Debt collection                  Payday loan
#
#                                            Issue  \
# 878845  Application, originator, mortgage broker
# 878846           Disclosure verification of debt
# 878847     Cont'd attempts collect debt not owed
#
#                                    Sub-issue  \
# 878845                                   NaN
# 878846  Not given enough info to verify debt
# 878847                      Debt is not mine
#
#                              Consumer complaint narrative  \
# 878845  I was contacted on XX/XX/XXXX email by XXXX fr...
# 878846                                                NaN
# 878847  I had a debit that was included in my chapter ...
#
#                                   Company public response  \
# ...

# %%
df_c_complaints.info()
#df_c_complaints.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878848 entries, 0 to 878847
# Data columns (total 18 columns):
# Date received                   878848 non-null object
# Product                         878848 non-null object
# Sub-product                     643688 non-null object
# Issue                           878848 non-null object
# Sub-issue                       405472 non-null object
# Consumer complaint narrative    186478 non-null object
# Company public response         245810 non-null object
# Company                         878848 non-null object
# State                           867328 non-null object
# ZIP code                        867277 non-null object
# Tags                            122573 non-null object
# Consumer consent provided?      348642 non-null object
# Submitted via                   878848 non-null object
# Date sent to company            878848 non-null object
# Company response to consumer    878848 non-null object
# ...

# %%
#print rows 7 - 14
df_c_complaints[7:14]#starts with row 7 but does print row 14
# Out:
#    Date received           Product                            Sub-product  \
# 7     06/15/2015  Credit reporting                                    NaN
# 8     11/13/2015          Mortgage                         Other mortgage
# 9     10/21/2014          Mortgage            Conventional fixed mortgage
# 10    04/14/2017          Mortgage                         Other mortgage
# 11    03/30/2012      Student loan               Non-federal student loan
# 12    02/03/2016   Debt collection  Other (i.e. phone, health club, etc.)
# 13    01/07/2015  Credit reporting                                    NaN
#
#                                        Issue  \
# 7   Credit reporting company's investigation
# 8   Loan modification,collection,foreclosure
# 9   Loan modification,collection,foreclosure
# 10  Loan modification,collection,foreclosure
# 11                        Repaying your loan
# 12           Disclosure verification of debt
# 13    Incorrect information on credit report
#
# ...

# %%
#df3 = pd.DataFrame(df_c_complaints['Product'].value_counts())
groupby_example = df_c_complaints.groupby('Product')

# %%
print(groupby_example.count().head(5)) # NOT NULL records within each column
print('\n')
print(groupby_example.size().tail(5)) # total records for each department
# Out:
#                              Date received  Sub-product  Issue  Sub-issue  \
# Product
# Bank account or service              86207        86207  86207          0
# Checking or savings account           8064         8064   8064       8061
# Consumer Loan                        31605        31605  31605          0
# Credit card                          89190            0  89190          0
# Credit card or prepaid card           9598         9598   9598       9500
#
#                              Consumer complaint narrative  \
# Product
# Bank account or service                             14897
# Checking or savings account                          1345
# Consumer Loan                                        9489
# Credit card                                         18846
# Credit card or prepaid card                          2177
#
#                              Company public response  Company  State  \
# Product
# ...

# %% [markdown]
# # Indexing Dataframes

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df2.set_index('day',inplace = True)

# %%
df2
# Out:
#           event  temp  windspeed
# day
# 1/1/2017  sunny    32          6
# 1/2/2017  sunny    35          7
# 1/3/2017  rainy    44          8
# 1/4/2017   snow    21         22
# 1/5/2017   snow    20         14
# 1/6/2017  rainy    17          7
# 1/7/2017   snow    21          5

# %%
df2.loc['1/3/2017']
# Out:
# event        rainy
# temp            44
# windspeed        8
# Name: 1/3/2017, dtype: object

# %%
df2.reset_index(inplace = True)

# %%
df2
# Out:
#         day  event  temp  windspeed
# 0  1/1/2017  sunny    32          6
# 1  1/2/2017  sunny    35          7
# 2  1/3/2017  rainy    44          8
# 3  1/4/2017   snow    21         22
# 4  1/5/2017   snow    20         14
# 5  1/6/2017  rainy    17          7
# 6  1/7/2017   snow    21          5

# %%
#Export dataframe contents as a .csv or .xlsx file
df2.to_csv('df2_content')
df2.to_csv('df2_content_2', encoding='utf-8', index=False)
with pd.ExcelWriter('df2_content.xlsx') as writer:
    df2.to_excel(writer,sheet_name = 'df2_content',index = False)

# %%
df2.to_csv('df2_content_c',columns=['day','temp'],encoding='utf-8', index=False)

# %%
df2.to_csv('df2_content_d',header = False,columns=['day','temp'],encoding='utf-8', index=False)

# %%
df = pd.read_csv("weather_data.csv")

# %%
df
# Out:
#        day   temp  windspeed  event
# 0  1/1/2017    32          6  sunny
# 1  1/2/2017    35          7  sunny
# 2  1/3/2017    44          8  rainy
# 3  1/4/2017    21         22   snow
# 4  1/5/2017    20         14   snow
# 5  1/6/2017    17          7  rainy
# 6  1/7/2017    21          5   snow

# %%
def event_changes(event):
    if event == 'snow':
        return 'really snowed that day'
    return event

df = pd.read_csv("weather_data.csv",converters = {
     'event': event_changes 
})

# %%
df
# Out:
#        day   temp  windspeed                   event
# 0  1/1/2017    32          6                   sunny
# 1  1/2/2017    35          7                   sunny
# 2  1/3/2017    44          8                   rainy
# 3  1/4/2017    21         22  really snowed that day
# 4  1/5/2017    20         14  really snowed that day
# 5  1/6/2017    17          7                   rainy
# 6  1/7/2017    21          5  really snowed that day

# %%
with pd.ExcelWriter('products_weather.xlsx') as writer:
    df.to_excel(writer,sheet_name = 'weather',index = False)
    df3.to_excel(writer,sheet_name = 'products')
